# %%
from bs4 import BeautifulSoup
import requests 
import re
import pandas as pd

# %% [markdown]
# ## First part - get Data: Basic functions that will be used
# Functions include:
# getPagesToCrawl - a function that creates a list of pages that should be used in order to achieve the full data.
# getTableDataFromPage - from a single page we get back a table that stores the data
# cleanHtmlCode - the first step that we take in order to clean our data, we remove the HTML from it and leave the info.
# createDf - gets 8 lists that contains data and return a df

# %%
def getPagesToCrawl():
    baseUrl="https://www.start.umd.edu/gtd/search/Results.aspx?page="
    amountPages = "&count=2000" 
    pageList = []
    
    for currentPageNumber in range(1,102):
        pageList.append(baseUrl + str(currentPageNumber) +amountPages)
        
    return pageList

# %%
def getTableDataFromPage(pageUrl):
    user_agent = {'User-agent': 'Mozilla/5.0'}
    response = requests.get(pageUrl,headers=user_agent)
    soup = BeautifulSoup(response.content, "html.parser")
    table = soup.find('table')
    return table

# %%
def cleanHtmlCode(tableData):
    GTD_ID = []
    DATE = []
    COUNTRY = []
    CITY = [] 
    PERPETRATOR_GROUP = []
    FATALITIES = []
    INJURED = []
    TARGET_TYPE = []

    listRows = []
    for tr in tableData.findAll("tr",attrs={}):
        for td in tr:
            if(td != "\n"):
                listRows.append(td.text)


    # A lot of data that we don't need (The name of the columns (8)) 
    for i in range(8):
        listRows.pop(0)
    
    for i in range(len(listRows)):
        iMod = i%8
        if(iMod == 0):
            GTD_ID.append(listRows[i])
        elif(iMod == 1):
            DATE.append(listRows[i])
        elif(iMod == 2):
            COUNTRY.append(listRows[i])
        elif(iMod == 3):
            CITY.append(listRows[i])
        elif(iMod == 4):
            PERPETRATOR_GROUP.append(listRows[i])
        elif(iMod == 5):
            FATALITIES.append(listRows[i])
        elif(iMod == 6):
            INJURED.append(listRows[i])
        elif(iMod == 7):
            TARGET_TYPE.append(listRows[i])
       
    
    return GTD_ID,DATE,COUNTRY,CITY,PERPETRATOR_GROUP,FATALITIES,INJURED,TARGET_TYPE

# %%
def createDf(GTD_ID,DATE,COUNTRY,CITY,PERPETRATOR_GROUP,FATALITIES,INJURED,TARGET_TYPE):
    df = pd.DataFrame({"GTD_ID":GTD_ID,
                   "DATE":DATE,
                   "COUNTRY":COUNTRY,
                   "CITY":CITY,
                   "PERPETRATOR_GROUP":PERPETRATOR_GROUP,
                   "FATALITIES":FATALITIES
                   ,"INJURED":INJURED,
                   "TARGET_TYPE":TARGET_TYPE,
                   })
    return df

# %% [markdown]
# ## First part - get Data: Flow

# %%
# 8 Lists that will store the data.
GTD_ID = []
DATE = []
COUNTRY = []
CITY = [] 
PERPETRATOR_GROUP = []
FATALITIES = []
INJURED = []
TARGET_TYPE = []

# %%
# First we Need the URLS which will be used by the crawlling method.
pageList = getPagesToCrawl()

# For each page inside our pageList:
for page in pageList:
    
    # Get the table data from the page with getTableDataFromPage function.
    tableData = getTableDataFromPage(page)
    
    # Extract 8 lists (according to parameter) with cleanHtmlCode function.
    GTD_ID_temp,DATE_temp,COUNTRY_temp,CITY_temp,PERPETRATOR_GROUP_temp,FATALITIES_temp,INJURED_temp,TARGET_TYPE_temp = cleanHtmlCode(tableData)
    
    # The the temp lists and EXTEND the data to non-temp list.
    GTD_ID.extend(GTD_ID_temp)
    DATE.extend(DATE_temp)
    COUNTRY.extend(COUNTRY_temp)
    CITY.extend(CITY_temp)
    PERPETRATOR_GROUP.extend(PERPETRATOR_GROUP_temp)
    FATALITIES.extend(FATALITIES_temp)
    INJURED.extend(INJURED_temp)
    TARGET_TYPE.extend(TARGET_TYPE_temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1656/1447512441.py in <module>
#       1 # First we Need the URLS which will be used by the crawlling method.
# ----> 2 pageList = getPagesToCrawl()
#       3
#       4 # For each page inside our pageList:
#       5 for page in pageList:
#
# NameError: name 'getPagesToCrawl' is not defined

# %%
# After the crawlling method is done all we have left to do is create a DF with createDf function and save the df to csv file.
df = createDf(GTD_ID,DATE,COUNTRY,CITY,PERPETRATOR_GROUP,FATALITIES,INJURED,TARGET_TYPE) 
df.to_csv('GTD_Data_Frame.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1656/1429289241.py in <module>
#       1 # After the crawlling method is done all we have left to do is create a DF with createDf function and save the df to csv file.
# ----> 2 df = createDf(GTD_ID,DATE,COUNTRY,CITY,PERPETRATOR_GROUP,FATALITIES,INJURED,TARGET_TYPE)
#       3 df.to_csv('GTD_Data_Frame.csv')
#
# NameError: name 'createDf' is not defined

# %%
# Reading the df once again to see that everything is ok
df = pd.read_csv('GTD_Data_Frame.csv')
df
# Out:
#         Unnamed: 0        GTD_ID        DATE             COUNTRY  \
# 0                0  201912310033  2019-12-31               China
# 1                1  201912310032  2019-12-31               India
# 2                2  201912310031  2019-12-31               Sudan
# 3                3  201912310030  2019-12-31               Sudan
# 4                4  201912310028  2019-12-31                Iraq
# ...            ...           ...         ...                 ...
# 301178      301178  197001000003  1970-01-00               Japan
# 301179      301179  197001000002  1970-01-00              Greece
# 301180      301180  197001000001  1970-01-00         Philippines
# 301181      301181  197000000002  1970-00-00              Mexico
# 301182      301182  197000000001  1970-07-02  Dominican Republic
#
#                  CITY                   PERPETRATOR_GROUP FATALITIES  INJURED  \
# 0           Hong Kong                             Unknown          0        0
# 1         Bagiot Dora                             Unknown          0        1
# 2          El Geneina                             Unknown          2        0
# 3          El Geneina                             Unknown          2        1
# 4             Baghdad                             Unknown          0        0
# ...               ...                                 ...        ...      ...
# 301178        Fukouka                             Unknown    Unknown  Unknown
# 301179         Athens                             Unknown    Unknown  Unknown
# 301180        Unknown                             Unknown          1        0
# 301181    Mexico city  23rd of September Communist League          0        0
# 301182  Santo Domingo                              MANO-D          1        0
#
#                         TARGET_TYPE
# 0              Government (General)
# 1       Private Citizens & Property
# 2       Government (General),Police
# 3                            Police
# 4       Private Citizens & Property
# ...                             ...
# 301178      Government (Diplomatic)
# 301179      Government (Diplomatic)
# 301180          Journalists & Media
# 301181      Government (Diplomatic)
# 301182  Private Citizens & Property
#
# [301183 rows x 9 columns]

# %%
df = df.drop_duplicates(subset=['GTD_ID'], keep='first')
df.to_csv('GTD_Data_Frame_Without_Duplicates.csv')

# %% [markdown]
# ##   Second part - Multi-Crawl
# ###  Get more data according to GTD_ID

# %%
def getLinksForSecondCrawl(GTD_ID):
    baseUrl = "https://www.start.umd.edu/gtd/search/IncidentSummary.aspx?gtdid="
    urlList = []
    
    for id in GTD_ID:
        urlList.append(baseUrl +str(id))
    
    return urlList

# %%
df = pd.read_csv('GTD_Data_Frame_Without_Duplicates.csv')

# %%
# GTD_ID will be used in order to get the pages which we need to crawl to get the data 
GTD_ID = df.GTD_ID

# %%
df[df["GTD_ID"] == 201912310018]
# Out:
#     Unnamed: 0  Unnamed: 0.1        GTD_ID        DATE COUNTRY           CITY  \
# 13          13            13  201912310018  2019-12-31   Yemen  Ataq district
#
#    PERPETRATOR_GROUP FATALITIES  INJURED           TARGET_TYPE
# 13    Al-Islah Party    Unknown  Unknown  Government (General)

# %%
urlList = getLinksForSecondCrawl(GTD_ID)

# %%
urlForCheck = "https://www.start.umd.edu/gtd/search/IncidentSummary.aspx?gtdid=201912270020"

# %%
response = requests.get(urlForCheck)
soup = BeautifulSoup(response.content, "html.parser")

# %%
def getMoreInfo(urlListToCrawl):
    temptd =soup.find_all("td",class_="value")
    templabel = soup.find_all("td",class_="label")
    attackType = []
    successfulAttack = []
    hostages =[]
    ransom = []
    propertyDamage = []
    suicideAttack = []
    partOfMultipleIncident = []

    for i in range(0,len(templabel)):
        count=1
        if templabel[i].text =="Type of Attack (more)":
            if count==2:
                attackType[i]+" "+temptd[i].text
            else:
                attackType.append(temptd[i].text)
                count++     
        if templabel[i].text == "Successful Attack? (more)":
            successfulAttack.append(temptd[i].text)
        if templabel[i].text == "Hostages":
            hostages.append(temptd[i].text)
        if templabel[i].text =="Ransom":
            ransom.append(temptd[i].text)
        if templabel[i].text =="Property Damage":
            propertyDamage.append(temptd[i].text)
        if templabel[i].text =="Suicide Attack?":
            propertyDamage.append(temptd[i].text)
        if templabel[i].text =="Part of Multiple Incident?":
            partOfMultipleIncident.append(temptd[i].text)
    return attackType,successfulAttack,hostages,ransom,propertyDamage,suicideAttack,partOfMultipleIncident

# %%
def takeInfo():
    df = pd.read_csv('GTD_Data_Frame_Without_Duplicates.csv')
    GTD_ID = df.GTD_ID
    urllinks = getLinksForSecondCrawl(GTD_ID)
    for link in urllinks:
        attackType,successfulAttack=getMoreInfo(link)
    return attackType,successfulAttack

# %%
attackType,successfulAttack=takeInfo()
print(attackType)
# Out:
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ...
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ['No']
# ['No']
# ['Unknown']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1656/4087074024.py in <module>
# ----> 1 attackType,successfulAttack=takeInfo()
#       2 print(attackType)
#
# ~\AppData\Local\Temp/ipykernel_1656/395528138.py in takeInfo()
#       8             break;
#       9         else:
# ---> 10             attackType,successfulAttack=getMoreInfo(link)
#      11     return attackType,successfulAttack
#      12
#
# ~\AppData\Local\Temp/ipykernel_1656/2846038844.py in getMoreInfo(urlListToCrawl)
#      25         if templabel[i].text =="Part of Multiple Incident?":
#      26             partOfMultipleIncident.append(temptd[i].text)
# ---> 27     print(attackType)
#      28     print(successfulAttack)
#      29     print(partOfMultipleIncident)
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Out:
# gnfgng
